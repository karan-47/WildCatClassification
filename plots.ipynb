# %%
import matplotlib.pyplot as plt

# Define the values
epochs = range(1, 11)
train_loss = [14.5336, 1.2534, 0.4695, 0.2158, 0.2639, 0.1397, 0.1939, 0.3692, 0.2591, 0.3104]
train_acc = [0.6033, 0.8943, 0.9560, 0.9744, 0.9707, 0.9822, 0.9765, 0.9738, 0.9780, 0.9702]
val_loss = [4.1302, 3.1559, 3.6325, 3.3122, 3.2307, 2.2215, 3.1981, 4.0850, 4.4325, 4.3699]
val_acc = [0.7448, 0.7887, 0.7720, 0.7887, 0.8285, 0.8640, 0.8180, 0.8326, 0.8389, 0.8159]

# Plot the loss values
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the accuracy values
plt.plot(epochs, train_acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the values
epochs = range(1, 11)
train_loss = [17.5772, 0.6574, 0.2767, 0.2296, 0.2284, 0.1156, 0.0590, 0.0612, 0.1484, 0.1310]
train_acc = [0.6337, 0.9246, 0.9665, 0.9723, 0.9754, 0.9838, 0.9906, 0.9911, 0.9864, 0.9885]
val_loss = [3.4935, 2.2084, 2.4765, 3.1954, 2.8430, 2.6585, 2.8106, 3.2493, 3.0831, 3.1503]
val_acc = [0.7594, 0.8368, 0.8347, 0.8201, 0.8305, 0.8452, 0.8368, 0.8159, 0.8368, 0.8347]

# Plot the accuracy values
plt.plot(epochs, train_acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot the loss values
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
