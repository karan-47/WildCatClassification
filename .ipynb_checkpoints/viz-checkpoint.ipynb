# %%
import os
import matplotlib.pyplot as plt

data_folder = 'train'
folder_names = os.listdir(data_folder)
num_objects = []

for folder_name in folder_names:
    folder_path = os.path.join(data_folder, folder_name)
    if os.path.isdir(folder_path):
        num_objects.append(len(os.listdir(folder_path)))

plt.plot(folder_names, num_objects)
plt.xticks(rotation=90)
plt.xlabel('Folder Name')
plt.ylabel('Number of Objects')
plt.title('Number of Objects per Folder')
plt.show()
print(sum(num_objects))
# Out:
# 2339

# %%
import os
import matplotlib.pyplot as plt

data_folder = 'test'
folder_names = os.listdir(data_folder)
num_objects = []

for folder_name in folder_names:
    folder_path = os.path.join(data_folder, folder_name)
    if os.path.isdir(folder_path):
        num_objects.append(len(os.listdir(folder_path)))

plt.plot(folder_names, num_objects)
plt.xticks(rotation=90)
plt.xlabel('Folder Name')
plt.ylabel('Number of Objects')
plt.title('Number of Objects per Folder')
plt.show()

# %%
import os
import matplotlib.pyplot as plt

data_folder = 'valid'
folder_names = os.listdir(data_folder)
num_objects = []

for folder_name in folder_names:
    folder_path = os.path.join(data_folder, folder_name)
    if os.path.isdir(folder_path):
        num_objects.append(len(os.listdir(folder_path)))

plt.plot(folder_names, num_objects)
plt.xticks(rotation=90)
plt.xlabel('Folder Name')
plt.ylabel('Number of Objects')
plt.title('Number of Objects per Folder')
plt.show()

# %%
from tensorflow.keras.utils import plot_model
import tensorflow as tf
model = tf.keras.models.load_model('models/base_vgg16.h5')
plot_model(model, to_file='model_architecture.pdf', show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
# !pip install graphviz

# %%
import pydot_ng as pydot
plot_model(model, to_file='model_architecture.pdf', show_shapes=True, expand_nested=True, dpi=96, prog=['dot'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 import pydot_ng as pydot
# ----> 2 plot_model(model, to_file='model_architecture.pdf', show_shapes=True, expand_nested=True, dpi=96, prog=['dot'])
#
# TypeError: plot_model() got an unexpected keyword argument 'prog'

# %%
# !pip install pydog_ng
# Out:
# ERROR: Could not find a version that satisfies the requirement pydog_ng (from versions: none)
# ERROR: No matching distribution found for pydog_ng

# %%
# !pip install pydot-ng

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import pydot_ng as pydot

model = tf.keras.models.load_model('models/base_vgg16.h5')
plot_model(model, to_file='model_architecture.pdf', show_shapes=True, expand_nested=True, dpi=96, 
           dotenv={"PATH": "C:\Program Files\Graphviz\bin\dot.exe"}, prog=["dot"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       3 import pydot_ng as pydot
#       5 model = tf.keras.models.load_model('models/base_vgg16.h5')
# ----> 6 plot_model(model, to_file='model_architecture.pdf', show_shapes=True, expand_nested=True, dpi=96,
#       7            dotenv={"PATH": "C:\Program Files\Graphviz\bin\dot.exe"}, prog=["dot"])
#
# TypeError: plot_model() got an unexpected keyword argument 'dotenv'

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

from tensorflow.keras.utils import plot_model
import tensorflow as tf

model = tf.keras.models.load_model('models/base_vgg16.h5')
plot_model(model, to_file='model_architecture.pdf', show_shapes=True, expand_nested=True, dpi=96, prog=['dot'])
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
from keras.utils.vis_utils import plot_model

import tensorflow as tf

model = tf.keras.models.load_model('models/base_vgg16.h5')
plot_model(model, to_file='model_architecture.png', show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from keras.utils.vis_utils import plot_model

import tensorflow as tf

model = tf.keras.models.load_model('models/vgg16_tl.h5')
# plot_model(model, to_file='base_model_architecture.png', show_shapes=True)

# %%
plot_model(model, to_file='base_model_architecture2.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 plot_model(model, to_file='base_model_architecture2.png', show_shapes=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\vis_utils.py:323, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi)
#     279 @keras_export('keras.utils.plot_model')
#     280 def plot_model(model,
#     281                to_file='model.png',
#    (...)
#     286                expand_nested=False,
#     287                dpi=96):
#     288   """Converts a Keras model to dot format and save to a file.
#     289
#     290   Example:
#    (...)
#     321     This enables in-line display of the model plots in notebooks.
#     322   """
# --> 323   dot = model_to_dot(
#     324       model,
#     325       show_shapes=show_shapes,
# ...

# %%
from keras.utils.vis_utils import plot_model

import tensorflow as tf

model = tf.keras.models.load_model('models/vgg16_tl.h5')
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                2570
# ...
# Total params: 21,140,042
# Trainable params: 6,425,354
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

import tensorflow as tf

model = tf.keras.models.load_model('models/base_vgg16.h5')
# plot_model(model, to_file='model_architecture.png', show_shapes=True)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...
